# %% [markdown]
# # Walk-Forward Backtesting: OU Process vs Classic Z-Score
#
# **Objective:** Build a production-grade walk-forward backtesting framework for credit spread mean reversion.
#
# ## Strategy Overview
#
# **Universe:** LQD (IG Corporate Bonds) vs IEF (7-10Y Treasuries)
#
# **Signals:**
# 1. **OU Process:** Model credit spreads as Ornstein-Uhlenbeck process, use OU-adjusted z-scores
# 2. **Classic Z-Score:** Simple rolling mean ± std deviation
#
# **Regime Filter:** 2-state HMM (Low Stress vs High Stress) with weekly recalibration
#
# **Position Sizing:** Duration-neutral (hedge interest rate risk)
#
# **Execution:** Daily, with realistic transaction costs
#
# **Key Principle:** Zero lookahead bias - simulate day-by-day as if living in the past.
#
# ---
